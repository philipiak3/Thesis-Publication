# %% [markdown]
# <a href="https://colab.research.google.com/github/philipiak3/Thesis-Publication/blob/main/PolypDetectionYOLOv7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/PolypDetectionHarv.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_64.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_65.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_66.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_67.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_68.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_69.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_7.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_70.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_71.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_72.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_73.jpg
#   inflating: /content/PolypDetectionHarv/valid/images/harvard__5_74.jpg
# ...

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git       # clone
# %cd yolov7
# !pip install -r requirements.txt      # install modules
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt # download pretrained weight
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197
# Receiving objects: 100% (1197/1197), 74.23 MiB | 47.00 MiB/s, done.
# Resolving deltas: 100% (519/519), done.
# /content/yolov7
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 53.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
# %cd yolov7/
# Out:
# /content/yolov7

# %%
# 16 BATCH SIZE - L4 GPU - 50 epochs.

# !python train.py --weights yolov7.pt --data "data/data.yaml" --workers 4 --batch-size 16 --img 416  --cfg cfg/training/yolov7.yaml --name yolov7 --epochs 50 --hyp data/hyp.scratch.p5.yaml
# Out:
# 2024-05-11 12:13:51.670223: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-11 12:13:51.722286: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-11 12:13:51.722331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-11 12:13:51.724156: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# 416 metrics on test data 16 batch size training - best results so far.
# !python test.py --task test --data data/data.yaml --batch-size 16 --img 416  --device 0 --weights runs/train/yolov7/weights/best.pt --name yolov7_416_test16
# Out:
# Namespace(weights=['runs/train/yolov7/weights/best.pt'], data='data/data.yaml', batch_size=16, img_size=416, conf_thres=0.001, iou_thres=0.65, task='test', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7_416_test16', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (NVIDIA L4, 22699.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %%
# Detection with bboxes on test images

# !python detect.py --weights runs/train/yolov7/weights/best.pt --img 416  --source "/content/PolypDetectionHarv/test/images"
# Out:
# Streaming output truncated to the last 5000 lines.
#  The image with the result is saved in: runs/detect/exp/harvard__1_67.jpg
# 1 polyp, Done. (6.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_68.jpg
# 1 polyp, Done. (6.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_69.jpg
# 1 polyp, Done. (6.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_7.jpg
# 1 polyp, Done. (6.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_70.jpg
# 1 polyp, Done. (6.7ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_71.jpg
# 1 polyp, Done. (7.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_72.jpg
# 1 polyp, Done. (6.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs/detect/exp/harvard__1_73.jpg
# ...

# %%
# Download the detections on the test images

import shutil
import os
from google.colab import files


folder_path = '/content/yolov7/runs/detect/exp'

zip_path = '/content/exp_final.zip'

shutil.make_archive('/content/exp_final', 'zip', folder_path)

shutil.move('/content/exp_final.zip', zip_path)

files.download(zip_path)

# %%
import shutil
import os
from google.colab import files


folder_path = '/content/yolov7/runs/test/yolov7_416_test16'

zip_path = '/content/test_final.zip'

shutil.make_archive('/content/test_final', 'zip', folder_path)

shutil.move('/content/test_final.zip', zip_path)

files.download(zip_path)
